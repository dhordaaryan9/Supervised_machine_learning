# %% [markdown]
# # 1. Create a Python script that generates two arrays: one representing the number of hours you spend on Instagram each day for a week, and the other representing your daily phone battery percentage at the end of the day. Plot these as a scatter plot using matplotlib.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
instagram_hours = np.random.uniform(1,6,7)
battery_percentage = np.random.randint(20,91,7)

# %%
plt.figure(figsize=(8,5))
plt.scatter(instagram_hours,battery_percentage, s=100, alpha=0.8)
plt.tight_layout()

# %% [markdown]
# # 2. Using scikit-learn's LinearRegression, fit a simple linear regression model to predict daily battery percentage based on Instagram usage hours from your generated data. Print the model's slope (coefficient) and intercept.

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
x = instagram_hours.reshape(-1,1)
y = battery_percentage

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
slope = model.coef_[0]
intercept = model.intercept_
print(f'Slope: {slope}')
print(f'Intercept: {intercept}')
# Out:
# Slope: -4.63392179010791
# Intercept: 64.05211452012009

# %% [markdown]
# **Slope (-4.63)**: This indicates a direct inverse relationship. For every 1 hour you spend scrolling on Instagram, your remaining phone battery drops by an average of 4.63%.
#
# **Intercept (64.05):** This represents the baseline value when your input is zero. If you spend 0 hours on Instagram during the day, your phone is predicted to end the day with 64.05% battery remaining.

# %% [markdown]
# # 3. Plot the regression line on top of your scatter plot to visualize the relationship between Instagram hours and battery percentage using matplotlib.<br><br><em><strong>Hint:</strong> Use model.predict() to get the predicted values for your x-axis data and plot them as a line.</em>

# %%
y_pred = model.predict(x)

# %%
plt.figure(figsize=(8,6))
plt.scatter(instagram_hours,battery_percentage,s=100, label='Actual Data')
plt.plot(instagram_hours,y_pred, linewidth=2.5, label=f'Regression Line (Slope: {slope:.2f})')
plt.tight_layout()

# %% [markdown]
# # 4. Calculate the mean squared error (MSE) between your actual battery percentages and the predicted values from your regression model using sklearn.metrics.mean_squared_error. Print the MSE value and explain in one line what a lower MSE indicates.

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(battery_percentage,y_pred)
mse
# Out:
# 399.86454232395744
